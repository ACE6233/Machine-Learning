# %% [markdown]
# <a href="https://colab.research.google.com/github/ACE6233/Machine-Learning/blob/main/DT2_Regression_(template).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the template Jupyter Notebook for the students to start working on the Regression problem in the DT2 Lab Experiment.

# %% [markdown]
# Load the modules and packages

# %%
import pandas as pd
from sklearn.model_selection import train_test_split as split
from sklearn.linear_model import LinearRegression as LR

# %% [markdown]
# Load the dataset

# %%
file = 'https://raw.githubusercontent.com/wooihaw/datasets/main/genders_heights_weights.csv'
df = pd.read_csv(file)

# %% [markdown]
# Check the dimension of the dataset

# %% [markdown]
# Examine the first few data samples

# %% [markdown]
# Randomly examine 10 data samples

# %% [markdown]
# Describe the statistics of the dataset

# %% [markdown]
# Height is the feature to be saved in X, whereas Weight is the label to be saved in y.

# %%
X = df.drop(columns=['Gender', 'Weight'])
y = df['Weight']

# %% [markdown]
# Split the dataset into 2 portions, i.e. training and testing datasets

# %%
X_train, X_test, y_train, y_test = split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# Examiner their respective dimensions

# %% [markdown]
# Regression Method 1. Linear Regression

# %%
# Initialize the linear regression model

# %% [markdown]
# Training

# %%
# Fit the model to the training data

# %% [markdown]
# Testing

# %%
# Evaluate the model's performance (choose your own evaluation metric, e.g., R2 score, Mean Squared Error, etc.)

# %% [markdown]
# Now let's make use of the Gender info

# %% [markdown]
# Encode Gender using *one-hot encoding*

# %%
df = pd.get_dummies(df, columns=['Gender'])
df.head()

# %% [markdown]
# Now X should store the Height & Gender, y still stores the Weight.

# %% [markdown]
# Similarly, split the dataset in the training and testing portions.

# %% [markdown]
# Training and testing with the 'new' dataset

# %%
# Initialize a new linear regression model


# Fit the model to the training data


# Evaluate the new model's performance

# %% [markdown]
# Has the coefficient of determination, R2 score changed? Why?

# %% [markdown]
# Answer: The R2 score has improved because the model with additional relevant features is more complete and better for the prediction.

# %% [markdown]
# Regression Method 2. k-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor as KNR

# %%
knr = KNR().fit(X_train, y_train)
score = knr.score(X_test, y_test)
print(f'KNR: R2 score (with gender info) is {score:.3f}')

# %% [markdown]
# What is the optimal number of nearest neighbors?
# *Hint*: Use a FOR loop
